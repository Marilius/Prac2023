# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import csv

# %%
data = {}
with open(r"./research.csv") as csvfile:
    csvreader = csv.reader(csvfile)
    for row in csvreader:
        if row[0] != "series":
            series, iter, mut_prob, time_sec, best_criterion = row
            if int(series) not in data:
                data[int(series)] = {}
            if int(iter) not in data[int(series)]:
                data[int(series)][int(iter)] = {
                    "mut_prob": float(mut_prob),
                    "time_sec": float(time_sec),
                    "best_criterion": int(best_criterion)
                }

# %%
data
# Out:
# {0: {0: {'mut_prob': 0.0004, 'time_sec': 29.829, 'best_criterion': 64},
#   1: {'mut_prob': 0.0004, 'time_sec': 23.2061, 'best_criterion': 57},
#   2: {'mut_prob': 0.0004, 'time_sec': 20.053, 'best_criterion': 67},
#   3: {'mut_prob': 0.0004, 'time_sec': 25.6259, 'best_criterion': 51},
#   4: {'mut_prob': 0.0004, 'time_sec': 19.3509, 'best_criterion': 52},
#   5: {'mut_prob': 0.0004, 'time_sec': 21.5164, 'best_criterion': 50},
#   6: {'mut_prob': 0.0004, 'time_sec': 17.3019, 'best_criterion': 50},
#   7: {'mut_prob': 0.0004, 'time_sec': 17.3581, 'best_criterion': 59},
#   8: {'mut_prob': 0.0004, 'time_sec': 20.1459, 'best_criterion': 57},
#   9: {'mut_prob': 0.0004, 'time_sec': 31.3685, 'best_criterion': 60}},
#  1: {0: {'mut_prob': 0.0006, 'time_sec': 19.1852, 'best_criterion': 56},
#   1: {'mut_prob': 0.0006, 'time_sec': 24.7832, 'best_criterion': 49},
#   2: {'mut_prob': 0.0006, 'time_sec': 17.7774, 'best_criterion': 53},
#   3: {'mut_prob': 0.0006, 'time_sec': 31.9154, 'best_criterion': 59},
#   4: {'mut_prob': 0.0006, 'time_sec': 15.1216, 'best_criterion': 56},
#   5: {'mut_prob': 0.0006, 'time_sec': 20.9893, 'best_criterion': 51},
#   6: {'mut_prob': 0.0006, 'time_sec': 15.1081, 'best_criterion': 60},
#   7: {'mut_prob': 0.0006, 'time_sec': 36.3103, 'best_criterion': 49},
#   8: {'mut_prob': 0.0006, 'time_sec': 22.7819, 'best_criterion': 57},
#   9: {'mut_prob': 0.0006, 'time_sec': 34.6477, 'best_criterion': 57}},
#  2: {0: {'mut_prob': 0.0009, 'time_sec': 21.0561, 'best_criterion': 51},
#   1: {'mut_prob': 0.0009, 'time_sec': 25.1197, 'best_criterion': 50},
#   2: {'mut_prob': 0.0009, 'time_sec': 17.1903, 'best_criterion': 56},
#   3: {'mut_prob': 0.0009, 'time_sec': 18.0816, 'best_criterion': 62},
#   4: {'mut_prob': 0.0009, 'time_sec': 19.5488, 'best_criterion': 64},
#   5: {'mut_prob': 0.0009, 'time_sec': 21.2822, 'best_criterion': 54},
#   6: {'mut_prob': 0.0009, 'time_sec': 24.0952, 'best_criterion': 53},
#   7: {'mut_prob': 0.0009, 'time_sec': 30.8027, 'best_criterion': 52},
#   8: {'mut_prob': 0.0009, 'time_sec': 16.3111, 'best_criterion': 50},
#   9: {'mut_prob': 0.0009, 'time_sec': 17.8535, 'best_criterion': 50}},
#  3: {0: {'mut_prob': 0.00135, 'time_sec': 40.462, 'best_criterion': 38},
#   1: {'mut_prob': 0.00135, 'time_sec': 24.5265, 'best_criterion': 66},
#   2: {'mut_prob': 0.00135, 'time_sec': 17.9703, 'best_criterion': 62},
#   3: {'mut_prob': 0.00135, 'time_sec': 17.1558, 'best_criterion': 61},
#   4: {'mut_prob': 0.00135, 'time_sec': 16.0906, 'best_criterion': 52},
#   5: {'mut_prob': 0.00135, 'time_sec': 18.4594, 'best_criterion': 61},
#   6: {'mut_prob': 0.00135, 'time_sec': 28.2507, 'best_criterion': 54},
#   7: {'mut_prob': 0.00135, 'time_sec': 29.7766, 'best_criterion': 41},
#   8: {'mut_prob': 0.00135, 'time_sec': 33.3247, 'best_criterion': 51},
#   9: {'mut_prob': 0.00135, 'time_sec': 31.5463, 'best_criterion': 61}},
#  4: {0: {'mut_prob': 0.002025, 'time_sec': 21.527, 'best_criterion': 54},
#   1: {'mut_prob': 0.002025, 'time_sec': 29.1595, 'best_criterion': 60},
#   2: {'mut_prob': 0.002025, 'time_sec': 28.7162, 'best_criterion': 61},
#   3: {'mut_prob': 0.002025, 'time_sec': 32.0713, 'best_criterion': 59},
#   4: {'mut_prob': 0.002025, 'time_sec': 19.4365, 'best_criterion': 65},
#   5: {'mut_prob': 0.002025, 'time_sec': 25.0401, 'best_criterion': 62},
#   6: {'mut_prob': 0.002025, 'time_sec': 14.9771, 'best_criterion': 63},
#   7: {'mut_prob': 0.002025, 'time_sec': 14.9177, 'best_criterion': 58},
#   8: {'mut_prob': 0.002025, 'time_sec': 14.7557, 'best_criterion': 51},
#   9: {'mut_prob': 0.002025, 'time_sec': 20.0691, 'best_criterion': 58}},
#  5: {0: {'mut_prob': 0.0030375, 'time_sec': 30.0791, 'best_criterion': 51},
#   1: {'mut_prob': 0.0030375, 'time_sec': 19.7705, 'best_criterion': 45},
#   2: {'mut_prob': 0.0030375, 'time_sec': 47.921, 'best_criterion': 55},
#   3: {'mut_prob': 0.0030375, 'time_sec': 24.7778, 'best_criterion': 42},
#   4: {'mut_prob': 0.0030375, 'time_sec': 24.5663, 'best_criterion': 54},
#   5: {'mut_prob': 0.0030375, 'time_sec': 33.7173, 'best_criterion': 49},
#   6: {'mut_prob': 0.0030375, 'time_sec': 30.8026, 'best_criterion': 52},
#   7: {'mut_prob': 0.0030375, 'time_sec': 17.6554, 'best_criterion': 62},
#   8: {'mut_prob': 0.0030375, 'time_sec': 37.766, 'best_criterion': 53},
#   9: {'mut_prob': 0.0030375, 'time_sec': 30.9991, 'best_criterion': 60}},
#  6: {0: {'mut_prob': 0.00455625, 'time_sec': 26.3386, 'best_criterion': 62},
#   1: {'mut_prob': 0.00455625, 'time_sec': 42.0515, 'best_criterion': 49},
#   2: {'mut_prob': 0.00455625, 'time_sec': 30.7752, 'best_criterion': 55},
#   3: {'mut_prob': 0.00455625, 'time_sec': 15.4247, 'best_criterion': 59},
#   4: {'mut_prob': 0.00455625, 'time_sec': 25.6942, 'best_criterion': 47},
#   5: {'mut_prob': 0.00455625, 'time_sec': 36.6874, 'best_criterion': 61},
#   6: {'mut_prob': 0.00455625, 'time_sec': 34.3799, 'best_criterion': 54},
#   7: {'mut_prob': 0.00455625, 'time_sec': 17.3257, 'best_criterion': 54},
#   8: {'mut_prob': 0.00455625, 'time_sec': 32.5922, 'best_criterion': 38},
#   9: {'mut_prob': 0.00455625, 'time_sec': 20.8586, 'best_criterion': 45}},
#  7: {0: {'mut_prob': 0.00683438, 'time_sec': 16.7154, 'best_criterion': 53},
#   1: {'mut_prob': 0.00683438, 'time_sec': 30.2365, 'best_criterion': 42},
#   2: {'mut_prob': 0.00683438, 'time_sec': 28.4153, 'best_criterion': 61},
#   3: {'mut_prob': 0.00683438, 'time_sec': 33.8682, 'best_criterion': 31},
#   4: {'mut_prob': 0.00683438, 'time_sec': 17.2542, 'best_criterion': 45},
#   5: {'mut_prob': 0.00683438, 'time_sec': 26.4948, 'best_criterion': 55},
#   6: {'mut_prob': 0.00683438, 'time_sec': 24.4244, 'best_criterion': 54},
#   7: {'mut_prob': 0.00683438, 'time_sec': 21.4786, 'best_criterion': 54},
#   8: {'mut_prob': 0.00683438, 'time_sec': 40.1505, 'best_criterion': 44},
#   9: {'mut_prob': 0.00683438, 'time_sec': 25.8106, 'best_criterion': 41}},
#  8: {0: {'mut_prob': 0.0102516, 'time_sec': 20.645, 'best_criterion': 52},
#   1: {'mut_prob': 0.0102516, 'time_sec': 27.8536, 'best_criterion': 51},
#   2: {'mut_prob': 0.0102516, 'time_sec': 16.2106, 'best_criterion': 53},
#   3: {'mut_prob': 0.0102516, 'time_sec': 21.6903, 'best_criterion': 56},
#   4: {'mut_prob': 0.0102516, 'time_sec': 31.7873, 'best_criterion': 53},
#   5: {'mut_prob': 0.0102516, 'time_sec': 21.4172, 'best_criterion': 56},
#   6: {'mut_prob': 0.0102516, 'time_sec': 35.3805, 'best_criterion': 58},
#   7: {'mut_prob': 0.0102516, 'time_sec': 15.5658, 'best_criterion': 57},
#   8: {'mut_prob': 0.0102516, 'time_sec': 25.5967, 'best_criterion': 61},
#   9: {'mut_prob': 0.0102516, 'time_sec': 20.3291, 'best_criterion': 59}},
#  9: {0: {'mut_prob': 0.0153773, 'time_sec': 16.5647, 'best_criterion': 41},
#   1: {'mut_prob': 0.0153773, 'time_sec': 16.8315, 'best_criterion': 53},
#   2: {'mut_prob': 0.0153773, 'time_sec': 18.7867, 'best_criterion': 56},
#   3: {'mut_prob': 0.0153773, 'time_sec': 17.6629, 'best_criterion': 57},
#   4: {'mut_prob': 0.0153773, 'time_sec': 29.5639, 'best_criterion': 53},
#   5: {'mut_prob': 0.0153773, 'time_sec': 17.8756, 'best_criterion': 49},
#   6: {'mut_prob': 0.0153773, 'time_sec': 15.5078, 'best_criterion': 52},
#   7: {'mut_prob': 0.0153773, 'time_sec': 24.2815, 'best_criterion': 40},
#   8: {'mut_prob': 0.0153773, 'time_sec': 15.0443, 'best_criterion': 60},
#   9: {'mut_prob': 0.0153773, 'time_sec': 33.6367, 'best_criterion': 56}}}

# %%
plt.figure(figsize=(15, 9))
plt.title("График зависимости стабильности алгоритма от значения Pmut")

diff = []
for i in data:
    a = [data[i][j]["best_criterion"] for j in data[i]]
    diff.append(max(a) - min(a))

plt.plot(range(len(data.keys())), diff, 'm')
plt.xticks(range(len(data.keys())))

plt.grid()
plt.show()

# %%
plt.figure(figsize=(15, 9))
plt.title("График зависимости качества работы алгоритма от значения Pmut")

diff = []
for i in data:
    a = [data[i][j]["best_criterion"] for j in data[i]]
    diff.append(max(a))

plt.plot(range(len(data.keys())), diff, 'm')
plt.xticks(range(len(data.keys())))

plt.grid()
plt.show()

# %%
plt.figure(figsize=(15, 9))
plt.title("График зависимости времени прогона от значения Pmut")

diff = []
for i in data:
    a = [data[i][j]["time_sec"] for j in data[i]]
    diff.append(max(a))

plt.plot(range(len(data.keys())), diff, 'm')
plt.xticks(range(len(data.keys())))

plt.grid()
plt.show()
